# %% [markdown]
# # Challenge

# %% [markdown]
# ## Introduction to dataset

# %%
import pandas as pd
all_age = pd.read_csv("all-ages.csv")
recent_grad = pd.read_csv("recent-grads.csv")

# %%
all_age.head() ## showing five fisrt element
# Out:
#     Major_code                                            Major  \
# 0         1100                              GENERAL AGRICULTURE
# 1         1101            AGRICULTURE PRODUCTION AND MANAGEMENT
# 2         1102                           AGRICULTURAL ECONOMICS
# 3         1103                                  ANIMAL SCIENCES
# 4         1104                                     FOOD SCIENCE
# ..         ...                                              ...
# 168       6211                           HOSPITALITY MANAGEMENT
# 169       6212    MANAGEMENT INFORMATION SYSTEMS AND STATISTICS
# 170       6299  MISCELLANEOUS BUSINESS & MEDICAL ADMINISTRATION
# 171       6402                                          HISTORY
# 172       6403                            UNITED STATES HISTORY
#
#                       Major_category     Total  Employed  \
# 0    Agriculture & Natural Resources  128148.0   90245.0
# 1    Agriculture & Natural Resources   95326.0   76865.0
# ...

# %%
recent_grad
# Out:
#     Rank  Major_code                                      Major  \
# 0      1      2419.0                      PETROLEUM ENGINEERING
# 1      2      2416.0             MINING AND MINERAL ENGINEERING
# 2      3      2415.0                  METALLURGICAL ENGINEERING
# 3      4      2417.0  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      5      2405.0                       CHEMICAL ENGINEERING
# ..   ...         ...                                        ...
# 168  169      3609.0                                    ZOOLOGY
# 169  170      5201.0                     EDUCATIONAL PSYCHOLOGY
# 170  171      5202.0                        CLINICAL PSYCHOLOGY
# 171  172      5203.0                      COUNSELING PSYCHOLOGY
# 172  173      3501.0                            LIBRARY SCIENCE
#
#                Major_category    Total  Sample_size      Men    Women  \
# 0                 Engineering   2339.0         36.0   2057.0    282.0
# ...

# %% [markdown]
# ##  Number of student by Major category

# %%
# Method Serie.unique allow you to get all unique catergorie of serie
# it means that you can group all of series
all_age["Major_category"]
# Out:
# 0      Agriculture & Natural Resources
# 1      Agriculture & Natural Resources
# 2      Agriculture & Natural Resources
# 3      Agriculture & Natural Resources
# 4      Agriculture & Natural Resources
#                     ...
# 168                           Business
# 169                           Business
# 170                           Business
# 171          Humanities & Liberal Arts
# 172          Humanities & Liberal Arts
# Name: Major_category, Length: 173, dtype: object

# %%
total = all_age["Total"]
total_is_null = pd.isnull(total)
total_is_null
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 168    False
# 169    False
# 170    False
# 171    False
# 172    False
# Name: Total, Length: 173, dtype: bool

# %%
total_null = total[total_is_null]
total_null
# Out:
# 113   NaN
# 136   NaN
# Name: Total, dtype: float64

# %%
## find total of student by category of major
def nb_stud_by_cat(df):
    category = df["Major_category"].unique()
    count_dictionary = {}
    
    for c in category:
        major_df = df[df["Major_category"]==c]
        total = major_df["Total"].sum()
        count_dictionary[c] = total
    return count_dictionary
aa_cat_count = nb_stud_by_cat(all_age)
ra_cat_count = nb_stud_by_cat(recent_grad)

# %%
aa_cat_count
# Out:
# {'Agriculture & Natural Resources': 632437.0,
#  'Biology & Life Science': 1338186.0,
#  'Engineering': 3576013.0,
#  'Humanities & Liberal Arts': 3738335.0,
#  'Communications & Journalism': 1803822.0,
#  'Computers & Mathematics': 1781378.0,
#  'Industrial Arts & Consumer Services': 1018072.0,
#  'Education': 4700118.0,
#  'Law & Public Policy': 902926.0,
#  'Interdisciplinary': 45199.0,
#  'Health': 2950859.0,
#  'Social Science': 2654125.0,
#  'Physical Sciences': 1013152.0,
#  nan: 0.0,
#  'Psychology & Social Work': 1987278.0,
#  'Arts': 1805865.0,
#  'Business': 9858741.0}

# %%
ra_cat_count
# Out:
# {'Engineering': 537583.0,
#  'Business': 1302376.0,
#  'Physical Sciences': 183363.0,
#  'Law & Public Policy': 179107.0,
#  'Computers & Mathematics': 299008.0,
#  'Agriculture & Natural Resources': 79981.0,
#  'Industrial Arts & Consumer Services': 227357.0,
#  'Arts': 357130.0,
#  'Health': 463230.0,
#  'Social Science': 529966.0,
#  nan: 0.0,
#  'Biology & Life Science': 453862.0,
#  'Education': 559129.0,
#  'Humanities & Liberal Arts': 713468.0,
#  'Psychology & Social Work': 481007.0,
#  'Communications & Journalism': 392601.0,
#  'Interdisciplinary': 12296.0}

# %% [markdown]
# ### Using pivot table method

# %%
import numpy
def nb_stud_by_cat_2(df):
    value = df.pivot_table(index="Major_category", values="Total", aggfunc=numpy.sum)
    return value

# %%
aa_cat_count_2 = nb_stud_by_cat_2(all_age)
aa_cat_count_2
# Out:
#                                          Total
# Major_category
# Agriculture & Natural Resources       632437.0
# Arts                                 1805865.0
# Biology & Life Science               1338186.0
# Business                             9858741.0
# Communications & Journalism          1803822.0
# Computers & Mathematics              1781378.0
# Education                            4700118.0
# Engineering                          3576013.0
# Health                               2950859.0
# Humanities & Liberal Arts            3738335.0
# Industrial Arts & Consumer Services  1018072.0
# Interdisciplinary                      45199.0
# Law & Public Policy                   902926.0
# Physical Sciences                    1013152.0
# Psychology & Social Work             1987278.0
# Social Science                       2654125.0

# %%
ra_cat_count_2 = nb_stud_by_cat_2(recent_grad)
ra_cat_count_2
# Out:
#                                          Total
# Major_category
# Agriculture & Natural Resources        79981.0
# Arts                                  357130.0
# Biology & Life Science                453862.0
# Business                             1302376.0
# Communications & Journalism           392601.0
# Computers & Mathematics               299008.0
# Education                             559129.0
# Engineering                           537583.0
# Health                                463230.0
# Humanities & Liberal Arts             713468.0
# Industrial Arts & Consumer Services   227357.0
# Interdisciplinary                      12296.0
# Law & Public Policy                   179107.0
# Physical Sciences                     183363.0
# Psychology & Social Work              481007.0
# Social Science                        529966.0

# %% [markdown]
# ## Low-wage employement rate

# %%
recent_grad[["Total", "Low_wage_jobs"]]
# Out:
#        Total  Low_wage_jobs
# 0     2339.0          193.0
# 1      756.0           50.0
# 2      856.0            0.0
# 3     1258.0            0.0
# 4    32260.0          972.0
# ..       ...            ...
# 168   8409.0          743.0
# 169   2854.0           82.0
# 170   2838.0          622.0
# 171   4626.0          308.0
# 172   1098.0          192.0
#
# [173 rows x 2 columns]

# %%
recent_grad_sum = recent_grad["Total"].sum()
Low_wage_jobs_sum = recent_grad["Low_wage_jobs"].sum()
Low_wage_jobs_proportion = Low_wage_jobs_sum/recent_grad_sum
Low_wage_jobs_proportion
# Out:
# 0.09856140415130317

# %% [markdown]
# ## Compare two dataset

# %%
major = recent_grad["Major"].unique()
rg_lower_count = 0
for f in major:
    all_age_row = all_age[all_age["Major"]==f]
    recent_grad_row = recent_grad[recent_grad["Major"]==f]
    
    val_2 = recent_grad_row["Unemployment_rate"].values
    val_1 = all_age_row["Unemployment_rate"].values
    if val_2 < val_1: rg_lower_count +=1
        
print(rg_lower_count)
# Out:
# c:\users\hp\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if __name__ == '__main__':
# c:\users\hp\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in less
#   if __name__ == '__main__':
# 42
